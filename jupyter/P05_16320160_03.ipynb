# %% [raw]
# nim/nama :16320160/Andry Dimas Putra
# tanggal  :15 Desember 2020
# deskripsi:pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("covid.csv")

# %% [markdown]
# ## 1. Histogram distribusi jumlah data per WHO region

# %% [markdown]
# ## 2. Line chart kasus terkonfirmasi di Indonesia

# %% [markdown]
# ## 3. Pie Chart banyaknya data masing-masing WHO Region

# %%
df["WHO Region"].value_counts().plot(kind = "pie")

# %% [markdown]
# ## 4. Scater Plot

# %%
df2 = df.loc[(df["Country/Region"] == "Malaysia")]
df2.plot(kind="scatter",x="Recovered",y="Deaths")
